# %% [markdown]
# Andrew:
#
# 1. By finetuning an LLM, you can get it to do what you want more consistently (compared to prompting).
# 2. Prompting an LLM to speak in a certain style (e.g., being more helpful / polite, or succint / verbose to a specific extent) can also be challenging. Finetuning turns out to be a good way to adjust an LLM's style (tone).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You'll learn how finetuning differs from prompting & RAG alone, and how these techniques can be used alongside finetuning.
